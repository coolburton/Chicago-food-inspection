# %%
import pandas as pd
import numpy as np

# %%
restaurants_pd = pd.read_csv("./updated_three_years.csv")
restaurants_pd.head()
# Out:
#    Inspection_ID                            AKA_name  \
# 0        2382240                 GROUND UP COFFEE CO
# 1        2374141             JUBILEE JUICE AND GRILL
# 2        2374101                     WALGREENS #4986
# 3        2374039  HEGEWISCH CHILD DEVELOPMENT CENTER
# 4        2374006       World's Finest Chocolate Inc.
#
#                      Facility_type             Risk              Address  \
# 0                       Restaurant  Risk 2 (Medium)       363 W ERIE ST
# 1                       Restaurant    Risk 1 (High)    140 N HALSTED ST
# 2                    Grocery Store     Risk 3 (Low)  4745 W BELMONT AVE
# 3  Daycare Above and Under 2 Years    Risk 1 (High)     2725 E 130TH ST
# 4                    Grocery Store     Risk 3 (Low)   4319 S Pulaski RD
#
#   Inspection_date        Inspection_type             Results  \
# 0      2020-06-25                License                Pass
# 1      2020-06-23  Canvass Re-Inspection  Pass w/ Conditions
# ...

# %%
violations_pd = pd.read_csv("./violations_codes.csv")
violations_pd.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9613b39ccafb> in <module>
# ----> 1 violations_pd = pd.read_csv("./violation_codes.csv")
#       2 violations_pd.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...
